# %%
import tweepy

# %%
import matplotlib.pyplot as plt
from textblob import TextBlob
import time

# %%
consumer_key = "B0eaoADDwAKd5cIsaZYwjCby4"
consumer_sec = "qsChoP8wBnEy4jicwKhNZyTp2IFvYupTc5FVWQlq6mfsyXqgjh"

# from proxy server we need to connect
access_token = "1376769887549333504-I4tnKx0SUswfIbgZrD2AsNuV61bw8o"
access_token_sec = "uoC9dCHtUxddfrMtCsDrljZxNgL2gGhdwulwcWqG45nUN"

# %%
auth=tweepy

# %%
#dir(tweepy)

# %%
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
auth.set_access_token(access_token,access_token_sec)

# %%
api_connect=tweepy.API(auth,)

# %%
tweet_data = api_connect.search('India',count=100)

# %%
positive=0
negative=0
neutral=0

# printing line by line
for tweet in tweet_data:
   #print(tweet.text)
   analysis=TextBlob(tweet.text) # here it will apply NLP\
   print(analysis.sentiment)
   # now checking polarity only
   if analysis.sentiment.polarity > 0:
      print("posative")
      positive=positive+1
   elif analysis.sentiment.polarity == 0 :
      print("Neutral")
      neutral=neutral+1
   else :
      print("Negative")
      negative=negative+1
# Out:
# Sentiment(polarity=0.6000000000000001, subjectivity=0.4)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.8, subjectivity=0.75)
# posative
# Sentiment(polarity=0.325, subjectivity=0.975)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.2, subjectivity=0.4)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=1.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=1.0, subjectivity=0.3)
# posative
# ...

# %%
#plotting
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[positive,negative,neutral])
plt.pie([positive,negative,neutral],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
